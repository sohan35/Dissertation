# %% [markdown]
# Chaturthi,Christmas,Diwali,NewYear in Mapusa_Ps , Anjuna_Ps

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Festival month mapping per year
festival_months_map = {
    2019: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2020: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2021: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2022: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2023: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2024: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1}
}

# Load dataset
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Filter for specific police stations
df = df[df['Police Station'].isin(['Mapusa_Ps', 'Anjuna_Ps'])]

# Extract year and month
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Month name mapping
month_names = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
               5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug',
               9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

# Prepare subplot layout
years = list(festival_months_map.keys())
n_years = len(years)
cols = 3
rows = (n_years + cols - 1) // cols  # Ceiling division

fig, axs = plt.subplots(rows, cols, figsize=(18, 10))
axs = axs.flatten()

for idx, year in enumerate(years):
    ax = axs[idx]
    fest_months = festival_months_map[year]
    monthly_counts = df[df['Year'] == year]['Month'].value_counts().sort_index()

    months = list(range(1, 13))
    counts = [monthly_counts.get(m, 0) for m in months]
    labels = [month_names[m] for m in months]

    # Assign colors
    colors = []
    for m in months:
        if m == fest_months['Ganesh']:
            colors.append('blue')
        elif m == fest_months['Diwali']:
            colors.append('orange')
        elif m == fest_months['Christmas']:
            colors.append('green')
        elif m == fest_months['New Year']:
            colors.append('red')
        else:
            colors.append('grey')

    bars = ax.bar(labels, counts, color=colors)
    ax.set_title(f"{year}")
    ax.set_xlabel("Month")
    ax.set_ylabel("Crimes")

    # Add bar labels
    for bar in bars:
        height = bar.get_height()
        if height > 0:
            ax.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{int(height)}',
                    ha='center', va='bottom', fontsize=8)

# Hide unused subplots
for j in range(idx + 1, len(axs)):
    fig.delaxes(axs[j])

# Legend
legend_elements = [
    Patch(facecolor='blue', label='Ganesh Chaturthi'),
    Patch(facecolor='orange', label='Diwali'),
    Patch(facecolor='green', label='Christmas'),
    Patch(facecolor='red', label='New Year'),
    Patch(facecolor='grey', label='Other Months')
]
fig.legend(handles=legend_elements, loc='upper center', ncol=5, fontsize=16)

plt.suptitle("  ", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 1])  # Leave space for suptitle
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Festival month mapping per year
festival_months_map = {
    2019: {'Ganesh': 9, 'Diwali': 10, 'Christmas': 12, 'New Year': 1},
    2020: {'Ganesh': 8, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2021: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2022: {'Ganesh': 9, 'Diwali': 10, 'Christmas': 12, 'New Year': 1},
    2023: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2024: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1}
}

# Load dataset
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Filter for specific police stations
df = df[df['Police Station'].isin(['Mapusa_Ps', 'Anjuna_Ps'])]

# Extract year and month
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Month name mapping
month_names = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
               5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug',
               9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

# Plot one graph per year
for year, fest_months in festival_months_map.items():
    monthly_counts = df[df['Year'] == year]['Month'].value_counts().sort_index()

    months = list(range(1, 13))
    counts = [monthly_counts.get(m, 0) for m in months]
    labels = [month_names[m] for m in months]

    # Print values with festival tags
    print(f"\nYear: {year}")
    for m, c in zip(months, counts):
        tag = ''
        if m == fest_months['Ganesh']:
            tag = '(Ganesh)'
        elif m == fest_months['Diwali']:
            tag = '(Diwali)'
        elif m == fest_months['Christmas']:
            tag = '(Christmas)'
        elif m == fest_months['New Year']:
            tag = '(New Year)'
        print(f"  {month_names[m]} {tag}: {c}")

    # Assign color based on festival month
    colors = []
    for m in months:
        if m == fest_months['Ganesh']:
            colors.append('blue')
        elif m == fest_months['Diwali']:
            colors.append('orange')
        elif m == fest_months['Christmas']:
            colors.append('green')
        elif m == fest_months['New Year']:
            colors.append('red')
        else:
            colors.append('grey')

    plt.figure(figsize=(10, 5))
    bars = plt.bar(labels, counts, color=colors)
    plt.title(f"Monthly Crime Count with Festival Highlights - {year} (Mapusa & Anjuna)")
    plt.xlabel("Month")
    plt.ylabel("Crime Count")

    # Add count labels
    for bar in bars:
        height = bar.get_height()
        if height > 0:
            plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{int(height)}',
                     ha='center', va='bottom', fontsize=9)

    # Custom legend
    legend_elements = [
        Patch(facecolor='blue', label='Ganesh Chaturthi'),
        Patch(facecolor='orange', label='Diwali'),
        Patch(facecolor='green', label='Christmas'),
        Patch(facecolor='red', label='New Year'),
        Patch(facecolor='grey', label='Other Months')
    ]
    plt.legend(handles=legend_elements)

    plt.tight_layout()
    plt.show()
# Out:
# Year: 2019
#   Jan (New Year): 5
#   Feb : 5
#   Mar : 9
#   Apr : 4
#   May : 3
#   Jun : 2
#   Jul : 3
#   Aug : 1
#   Sep (Ganesh): 5
#   Oct (Diwali): 8
#   Nov : 4
#   Dec (Christmas): 7
# Year: 2020
#   Jan (New Year): 11
#   Feb : 2
#   Mar : 5
#   Apr : 7
#   May : 0
#   Jun : 3
#   Jul : 3
#   Aug (Ganesh): 3
#   Sep : 2
#   Oct : 7
#   Nov (Diwali): 5
#   Dec (Christmas): 5
# Year: 2021
#   Jan (New Year): 11
#   Feb : 3
#   Mar : 8
#   Apr : 5
#   May : 8
#   Jun : 3
#   Jul : 7
#   Aug : 11
#   Sep (Ganesh): 12
#   Oct : 5
#   Nov (Diwali): 3
#   Dec (Christmas): 5
# Year: 2022
#   Jan (New Year): 10
#   Feb : 8
#   Mar : 10
#   Apr : 7
#   May : 7
#   Jun : 8
#   Jul : 6
#   Aug : 10
#   Sep (Ganesh): 7
#   Oct (Diwali): 1
#   Nov : 5
#   Dec (Christmas): 3
# Year: 2023
#   Jan (New Year): 3
#   Feb : 7
#   Mar : 2
#   Apr : 5
#   May : 6
#   Jun : 4
#   Jul : 6
#   Aug : 1
#   Sep (Ganesh): 0
#   Oct : 9
#   Nov (Diwali): 5
#   Dec (Christmas): 12
# Year: 2024
# ...

# %% [markdown]
# Average of all months in a year

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.patches import Patch

# Festival month mapping per year
festival_months_map = {
    2019: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2020: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2021: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2022: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2023: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2024: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1}
}

# Load and preprocess data
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])
df = df[df['Police Station'].isin(['Mapusa_Ps', 'Anjuna_Ps'])]

# Extract month and year
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Count crimes per month (across all years)
month_crime_totals = df['Month'].value_counts().sort_index()
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_crime_totals.index = month_names

# Reverse map: which festival is in which month
month_festival_map = defaultdict(set)
for year, festivals in festival_months_map.items():
    for fest, month in festivals.items():
        month_festival_map[month].add(fest)

# Assign specific color per festival (priority-based)
festival_colors = {
    'Ganesh': 'blue',
    'Diwali': 'orange',
    'Christmas': 'green',
    'New Year': 'red'
}
default_color = 'grey'

month_colors = []
for i in range(1, 13):  # Months 1 to 12
    festivals = month_festival_map[i]
    if festivals:
        # Just pick the first festival that appears (for color assignment)
        fest = sorted(festivals)[0]  # Ensures consistent selection
        color = festival_colors.get(fest, default_color)
    else:
        color = default_color
    month_colors.append(color)

# Plot
plt.figure(figsize=(10, 6))
bars = plt.bar(month_names, month_crime_totals, color=month_colors, width=0.5)

# Add title and labels
plt.title("Total Crimes per Month (Mapusa & Anjuna, 2019–2024)")
plt.xlabel("Month")
plt.ylabel("Total Crime Count")

# Add value labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1, str(height),
             ha='center', va='bottom', fontsize=9)

# Custom legend
legend_elements = [
     Patch(facecolor='blue', label='Ganesh Chaturthi'),
    Patch(facecolor='orange', label='Diwali'),
    Patch(facecolor='green', label='Christmas'),
    Patch(facecolor='red', label='New Year'),
    Patch(facecolor='grey', label='Other Months')
]
plt.legend(handles=legend_elements)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and preprocess dataset
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Filter for Mapusa_Ps and Anjuna_Ps
df = df[df['Police Station'].isin(['Mapusa_Ps', 'Anjuna_Ps'])]

# Extract year, month, and day
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Filter for month-end crimes (29th, 30th, 31st)
month_end_df = df[df['Day'].isin([26,27,28,29, 30, 31,1,2,3,4])]

# Count total crimes per month-end
month_end_counts = month_end_df.groupby(['Year', 'Month']).size().reset_index(name='Crime_Count')

# Print the table
#print("Month-End Crimes (29th–31st):")
#Sprint(month_end_counts)

# Plotting
month_end_df['Month_Name'] = month_end_df['Month'].apply(lambda x: pd.to_datetime(f'2024-{x}-01').strftime('%b'))

# Total count per month (across all years)
monthly_totals = month_end_df['Month_Name'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
bars = plt.bar(monthly_totals.index, monthly_totals.values, color='lightblue', width=0.5)
plt.title("Total Crimes During Month-End (29th–31st) in Mapusa & Anjuna")
plt.xlabel("Month")
plt.ylabel("Crime Count")

# Add labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, str(height),
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14216\4151821439.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_end_df['Month_Name'] = month_end_df['Month'].apply(lambda x: pd.to_datetime(f'2024-{x}-01').strftime('%b'))

# %% [markdown]
# Chaturthi,Christmas,Diwali,NewYear in Colvale_PS

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Festival month mapping per year
festival_months_map = {
    2021: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2022: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2023: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2024: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1}
}

# Load dataset
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Filter for specific police stations
df = df[df['Police Station'].isin(['Colvale_PS'])]

# Extract year and month
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Month name mapping
month_names = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
               5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug',
               9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

# Prepare subplot layout
years = list(festival_months_map.keys())
n_years = len(years)
cols = 3
rows = (n_years + cols - 1) // cols  # Ceiling division

fig, axs = plt.subplots(rows, cols, figsize=(18, 10))
axs = axs.flatten()

for idx, year in enumerate(years):
    ax = axs[idx]
    fest_months = festival_months_map[year]
    monthly_counts = df[df['Year'] == year]['Month'].value_counts().sort_index()

    months = list(range(1, 13))
    counts = [monthly_counts.get(m, 0) for m in months]
    labels = [month_names[m] for m in months]

    # Assign colors
    colors = []
    for m in months:
        if m == fest_months['Ganesh']:
            colors.append('blue')
        elif m == fest_months['Diwali']:
            colors.append('orange')
        elif m == fest_months['Christmas']:
            colors.append('green')
        elif m == fest_months['New Year']:
            colors.append('red')
        else:
            colors.append('grey')

    bars = ax.bar(labels, counts, color=colors)
    ax.set_title(f"{year}")
    ax.set_xlabel("Month")
    ax.set_ylabel("Crimes")

    # Add bar labels
    for bar in bars:
        height = bar.get_height()
        if height > 0:
            ax.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{int(height)}',
                    ha='center', va='bottom', fontsize=8)

# Hide unused subplots
for j in range(idx + 1, len(axs)):
    fig.delaxes(axs[j])

# Legend
legend_elements = [
    Patch(facecolor='blue', label='Ganesh Chaturthi'),
    Patch(facecolor='orange', label='Diwali'),
    Patch(facecolor='green', label='Christmas'),
    Patch(facecolor='red', label='New Year'),
    Patch(facecolor='grey', label='Other Months')
]
fig.legend(handles=legend_elements, loc='upper center', ncol=5, fontsize=16)

plt.suptitle("  ", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 1])  # Leave space for suptitle
plt.show()

# %% [markdown]
# Average of all months in a year

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.patches import Patch

# Festival month mapping per year
festival_months_map = {
    2021: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2022: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2023: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1},
    2024: {'Ganesh': 9, 'Diwali': 11, 'Christmas': 12, 'New Year': 1}
}

# Load and preprocess data
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])
df = df[df['Police Station'].isin(['Colvale_PS'])]

# Extract month and year
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Count crimes per month (across all years)
month_crime_totals = df['Month'].value_counts().sort_index()
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_crime_totals.index = month_names

# Reverse map: which festival is in which month
month_festival_map = defaultdict(set)
for year, festivals in festival_months_map.items():
    for fest, month in festivals.items():
        month_festival_map[month].add(fest)

# Assign specific color per festival (priority-based)
festival_colors = {
    'Ganesh': 'Blue',
    'Diwali': 'orange',
    'Christmas': 'green',
    'New Year': 'red'
}
default_color = 'grey'

month_colors = []
for i in range(1, 13):  # Months 1 to 12
    festivals = month_festival_map[i]
    if festivals:
        # Just pick the first festival that appears (for color assignment)
        fest = sorted(festivals)[0]  # Ensures consistent selection
        color = festival_colors.get(fest, default_color)
    else:
        color = default_color
    month_colors.append(color)

# Plot
plt.figure(figsize=(10, 6))
bars = plt.bar(month_names, month_crime_totals, color=month_colors, width=0.5)

# Add title and labels
plt.title("Total Crimes per Month (Colvale, 2021–2024)")
plt.xlabel("Month")
plt.ylabel("Total Crime Count")

# Add value labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1, str(height),
             ha='center', va='bottom', fontsize=9)

# Custom legend
legend_elements = [
    Patch(facecolor='blue', label='Ganesh Chaturthi'),
    Patch(facecolor='orange', label='Diwali'),
    Patch(facecolor='green', label='Christmas'),
    Patch(facecolor='red', label='New Year'),
    Patch(facecolor='grey', label='Other Months')
]
plt.legend(handles=legend_elements)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and preprocess dataset
df = pd.read_csv('sy.csv', encoding='latin1')
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df = df.dropna(subset=['Date'])

# Filter for Colvale_PS
df = df[df['Police Station'].isin(['Colvale_PS'])]

# Extract year, month, and day
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Filter for month-end crimes (26th to 4th)
month_end_df = df[df['Day'].isin([26, 27, 28, 29, 30, 31, 1, 2, 3, 4])]

# Add month name for grouping and plotting
month_end_df['Month_Name'] = month_end_df['Month'].apply(lambda x: pd.to_datetime(f'2024-{x}-01').strftime('%b'))

# Total count per month (across all years)
monthly_totals = month_end_df['Month_Name'].value_counts().sort_index()

# Define distinct colors for months
colors = {
    'Jan': '#FF9999', 'Feb': '#FFCC99', 'Mar': '#FFFF99', 'Apr': '#CCFF99',
    'May': '#99FF99', 'Jun': '#99FFCC', 'Jul': '#99FFFF', 'Aug': '#99CCFF',
    'Sep': '#9999FF', 'Oct': '#CC99FF', 'Nov': '#FF99CC', 'Dec': '#FF6666'
}

month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Filter and order months in the data
monthly_totals = monthly_totals.reindex(month_order).dropna()

# Plot
plt.figure(figsize=(12, 6))
bars = plt.bar(monthly_totals.index, monthly_totals.values,
               color=[colors[m] for m in monthly_totals.index], width=0.5)

plt.title("Total Crimes During Month-End (26th – 4th) in Colvale", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Crime Count", fontsize=12)

# Add count labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5,
             str(int(height)), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27272\1581549920.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_end_df['Month_Name'] = month_end_df['Month'].apply(lambda x: pd.to_datetime(f'2024-{x}-01').strftime('%b'))
